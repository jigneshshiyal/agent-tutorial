# %%
from dotenv import load_dotenv
import os

load_dotenv()

GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    api_key=GEMINI_API_KEY,
    
)

# %% [markdown]
# #### Simple stream and invoke

# %%
from langgraph.graph import StateGraph, START, END, MessagesState
from langchain_core.messages import BaseMessage
from langgraph.checkpoint.memory import MemorySaver

checkpoint = MemorySaver()

def call_model(state: MessagesState):
    response = llm.invoke(state["messages"])
    return {"messages": response.content}

workflow = (
    StateGraph(MessagesState)
    .add_node("call_model", call_model)
    .add_edge(START, "call_model")
    .add_edge("call_model", END)
    .compile(checkpointer=checkpoint)
)

# %%
import uuid

config = {
    "configurable":{
        "thread_id": str(uuid.uuid4())
    }
}

# %%
for chunk, metadata in workflow.stream({"messages":"what is space? explain in long asnwer"}, stream_mode="messages", config=config):
    if chunk.content:
        print(chunk.content, end="\n\n")
# Out:
# Here are two explanations of space:
#
# **What is space? (Short Answer)**
#
# Space is the vast, three-dimensional expanse that contains all matter and energy in the universe, serving as the fundamental stage
#
#  upon which all physical events unfold.
#
# **What is space? (Long Answer)**
#
# Space, in its most profound sense, is the **three-dimensional expanse that contains all matter and energy in the universe, serving as the fundamental stage upon
#
#  which all physical events unfold.** It's not merely an empty void, but a dynamic and complex component of reality as understood by modern physics.
#
# Here's a detailed explanation:
#
# 1.  **The Cosmic Container:** At its
#
#  most fundamental level, space is the "container" or "arena" where everything we observe exists: planets, stars, galaxies, dust, gas, light, and all forms of energy. It defines the distances between objects and the directions in
#
#  which they are located, providing the framework for the universe's structure.
#
# 2.  **Mostly a Vacuum, But Not Truly Empty:** While space is often described as a vacuum, implying it's completely empty, this isn'
#
# t entirely accurate. Interstellar and intergalactic space are largely devoid of matter, but they do contain trace amounts of gas, dust, plasma, and various forms of radiation (like light, radio waves, and X-rays). Furthermore,
#
#  according to quantum mechanics, even a perfect vacuum is teeming with "virtual particles" that constantly pop in and out of existence for fleeting moments, a phenomenon related to what's known as the quantum foam or zero-point energy.
#
# 3
#
# .  **A Dynamic Fabric: Spacetime:** Perhaps the most revolutionary understanding of space comes from Albert Einstein's theories of relativity. He demonstrated that space is not a static, passive backdrop, but is inextricably linked with time, forming
#
#  a unified four-dimensional continuum called **spacetime**.
#     *   **Curvature and Gravity:** According to Einstein's General Theory of Relativity, massive objects (like stars, planets, and black holes) warp or curve spacetime around
#
#  them, much like a heavy ball creates a dip in a stretched rubber sheet. This curvature of spacetime is what we perceive as gravity. Objects don't "fall" because a force pulls them; instead, they follow the shortest paths (
#
# geodesics) through the curved spacetime created by other masses.
#     *   **Expansion of the Universe:** Another profound aspect of spacetime is its expansion. The universe itself is not merely expanding *into* a pre-existing, fixed
#
#  space; rather, space *itself* is stretching and growing, carrying galaxies along with it. This expansion is a fundamental property of space, causing the distances between unbound galaxies to increase over cosmic time.
#
# 4.  **Contents and
#
#  Properties:** Space possesses measurable properties and is filled with various components:
#     *   It is permeated by the **Cosmic Microwave Background (CMB) radiation**, a faint glow of electromagnetic radiation left over from the Big Bang, providing crucial
#
#  evidence for the universe's origin.
#     *   It is also filled with mysterious components like **dark matter** and **dark energy**. Dark matter, which doesn't interact with light, is inferred by its gravitational effects on galaxies
#
#  and galaxy clusters. Dark energy is an even more enigmatic force, believed to be responsible for the accelerating expansion of the universe. These components profoundly influence the large-scale structure and evolution of the cosmos.
#
# In summary, space is far more
#
#  than just the absence of things. It is the fundamental, dynamic stage upon which the cosmic drama unfolds – a three-dimensional component of spacetime, interwoven with time, shaped by matter and energy, and itself shaping the evolution of the universe.
#
#  Its true nature, especially at the most extreme scales (such as within black holes or at the moment of the Big Bang), remains one of the most profound and active areas of research in modern physics.

# %% [markdown]
# #### Use Async Steam

# %%
from langgraph.graph import StateGraph, START, END, MessagesState
from langchain_core.messages import BaseMessage
from langgraph.checkpoint.memory import MemorySaver

checkpoint = MemorySaver()

async def call_model(state: MessagesState):
    async for chunk in llm.astream(state["messages"]):
        yield {"token": chunk.content}

workflow = (
    StateGraph(MessagesState)
    .add_node("call_model", call_model)
    .add_edge(START, "call_model")
    .add_edge("call_model", END)
    .compile(checkpointer=checkpoint)
)

# %%
async for chunk, metadata in workflow.astream({"messages":"what is space? explain in long asnwer"}, stream_mode="messages", config=config):
    if chunk.content:
        print(chunk.content, end="\n\n")
# Out:
# Space, at its most fundamental, is the **boundless three-dimensional extent in which objects and events have relative position and direction**. It is the stage upon which the entire universe plays out, a concept that has evolved dramatically from ancient
#
#  philosophical ideas to the complex scientific understanding we have today.
#
# Here's a long explanation of what space is:
#
# ---
#
# ### 1. The "Empty" Canvas: A Vast Near-Vacuum
#
# At its most intuitive level, space is
#
#  perceived as the vast, dark "emptiness" between celestial bodies. Beyond Earth's atmosphere, the air thins out rapidly, leading to a near-perfect vacuum. This "empty" space is characterized by:
#
# *   **Ext
#
# remely Low Density:** While not absolutely empty, it contains very few particles per unit volume – far fewer than even the best vacuums created on Earth. These particles mostly consist of isolated hydrogen and helium atoms, plasma, and cosmic dust, collectively
#
#  known as the **interstellar medium** within galaxies, and the **intergalactic medium** between galaxies.
# *   **Absence of Atmospheric Pressure:** There's no air pressure as we know it, which is why astronauts need pressurized
#
#  suits, and liquids boil instantly in the vacuum.
# *   **Extreme Cold:** Far from stars or heat sources, the temperature of space is incredibly low, hovering around 2.7 Kelvin (-270.45 °C or -
#
# 454.81 °F) – the temperature of the **Cosmic Microwave Background (CMB)** radiation, the afterglow of the Big Bang.
#
# ### 2. The Container of Everything: Dimensions and Scale
#
# Space
#
#  is the container for all matter and energy in the universe. It provides the dimensions necessary for objects to exist and events to occur:
#
# *   **Three Spatial Dimensions:** We perceive space in three dimensions: length, width, and height (
#
# or depth). Any point in space can be uniquely identified by three coordinates. This is the "Euclidean" space we intuitively understand.
# *   **Vastness:** The scale of space is mind-boggling. Distances are
#
#  measured in light-years (the distance light travels in one year, about 9.46 trillion kilometers or 5.88 trillion miles) or parsecs. We speak of interstellar space (between stars within a galaxy), inter
#
# galactic space (between galaxies), and the vast cosmic web that connects clusters of galaxies.
#
# ### 3. Spacetime: The Fabric of the Universe
#
# The modern understanding of space was revolutionized by Albert Einstein's theories of **Relativity**:
#
#
#
# *   **Interwoven with Time:** Einstein showed that space and time are not separate entities but are interwoven into a single, four-dimensional fabric called **spacetime**. Events occur not just at a certain place, but also at a certain time
#
# . This means that space and time are relative; their measurements depend on the observer's motion.
# *   **Curvature and Gravity:** One of the most profound implications of spacetime is that it can be curved or warped by the presence of mass and
#
#  energy. What we perceive as **gravity** is not a force pulling objects together, but rather the manifestation of objects moving along the shortest paths (geodesics) through curved spacetime. Imagine a heavy bowling ball placed on a stretched rubber sheet
#
#  – it creates a dip. A marble rolling nearby will be drawn towards the bowling ball not because it's pulled, but because the sheet itself is curved. Similarly, planets orbit stars because the star's mass warps the spacetime around it.
#
#
# *   **Dynamic and Expanding:** Spacetime is not a static background. Observations by Edwin Hubble showed that the universe is expanding, meaning that the fabric of spacetime itself is stretching, carrying galaxies further apart from each other. This expansion is accelerating
#
# , a phenomenon attributed to a mysterious force called **dark energy**. It's crucial to understand that galaxies aren't just moving *through* space, but space *itself* is expanding between them.
#
# ### 4. Key Characteristics and
#
#  Phenomena within Space
#
# Beyond its fundamental nature, space exhibits several important characteristics:
#
# *   **Cosmic Microwave Background (CMB) Radiation:** Space is permeated by the CMB, a uniform radiation field that is the remnant heat from the Big Bang
#
# . It's evidence that the universe started from a hot, dense state and has been expanding and cooling ever since.
# *   **Cosmic Rays:** High-energy particles (mostly protons and atomic nuclei) constantly bombard Earth from all
#
#  directions. These cosmic rays originate from various sources like supernovae, active galactic nuclei, and potentially even more exotic phenomena.
# *   **Electromagnetic Radiation:** Space is filled with electromagnetic radiation across the entire spectrum, from radio waves and microwaves to
#
#  visible light, X-rays, and gamma rays. This radiation carries information about distant celestial objects and processes.
# *   **Dark Matter and Dark Energy:** While we can't directly observe them, the vast majority of the universe's mass and
#
#  energy content is believed to be made up of **dark matter** (which exerts gravitational pull but doesn't interact with light) and **dark energy** (which drives the accelerating expansion of space). These mysterious components are fundamental to understanding the large
#
# -scale structure and evolution of space.
#
# ### 5. Why Understanding Space Matters
#
# Understanding space is not merely an academic exercise; it's fundamental to:
#
# *   **Cosmology:** It allows us to study the origin
#
# , evolution, and ultimate fate of the universe.
# *   **Physics:** Space is the ultimate laboratory for testing the laws of physics under extreme conditions, from the smallest subatomic particles to the largest cosmic structures.
# *   **Astronomy
#
# :** It provides the context for observing and understanding stars, galaxies, black holes, and other celestial phenomena.
# *   **Human Exploration and Future:** Space exploration pushes the boundaries of human knowledge and technology, offering potential for resources, new frontiers
#
# , and perhaps even understanding our place in the cosmos.
#
# ---
#
# In summary, space is far more than just "nothingness." It is the dynamic, four-dimensional fabric of spacetime, warped by matter and energy, expanding and evolving
#
# , and containing all the wonders and mysteries of the universe. It is the fundamental canvas upon which reality is painted, constantly challenging our perceptions and inspiring scientific inquiry.
