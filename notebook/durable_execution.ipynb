# %%
# requirements
# 1. persistence 
# 2. thread identifier 
# 3. wrap non-deterministic operations inside tasks

# %%
# durability mode
# exit -> save checkpoint at graph execution
# async -> changes persisted async 
# sync -> first save and after execute next step

# %%
# resume workflow
# pausing and resuming workflow -> interrupt function to pause, command to resume it with updated state
