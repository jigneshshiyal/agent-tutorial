# %%
from dotenv import load_dotenv
import os

load_dotenv()

GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# %% [markdown]
# ### integrate with langchain

# %%
from langchain_google_genai import GoogleGenerativeAI


chain = GoogleGenerativeAI(model="models/gemini-2.5-flash", api_key=GEMINI_API_KEY)

# %%
from langfuse import Langfuse
from langfuse.langchain import CallbackHandler

langfuse = Langfuse(
    public_key="pk-lf-d3f8c178-97e8-4ea7-b4d9-e1464d998f6c",
    secret_key="sk-lf-52434f09-f183-48a5-bd34-5bb8a4aba6cd",
    host="http://localhost:3000"
)

langfuse_handler = CallbackHandler()

# <Your Langchain code here>
 
# Add handler to run/invoke/call/chat
chain.invoke("hello", config={"callbacks": [langfuse_handler]})
# Out:
# 'Hello! How can I help you today?'

# %% [markdown]
# ### integrate with langraph

# %%
from langgraph.func import task, entrypoint
from dataclasses import dataclass
from langgraph.graph import StateGraph, START
from langchain.chat_models import init_chat_model

llm = init_chat_model(
    model_provider="google_genai",
    model="models/gemini-2.5-flash",
    api_key=GEMINI_API_KEY
)

llm = init_chat_model(
    model_provider="google_genai",
    model="models/gemini-2.5-flash",
    api_key=GEMINI_API_KEY
)

@dataclass
class MyState:
    topic: str
    joke: str = ""

def call_model(state: MyState):
    """Call the LLM to generate a joke about a topic"""
    llm_response = llm.invoke( 
        [
            {"role": "user", "content": f"{state.topic}"}
        ]
    )
    return {"joke": llm_response.content}

graph = (
    StateGraph(MyState)
    .add_node(call_model)
    .add_edge(START, "call_model")
    .compile().with_config({"callbacks":[langfuse_handler]})
)

# %%
for message_chunk, metadata in graph.stream( 
    {"topic": "what is space?"},
    stream_mode="messages",
):
    if message_chunk.content:
        print(message_chunk.content, end="|", flush=True)
# Out:
# "Space" is one of the most fundamental and complex concepts in physics and philosophy, and its definition has evolved significantly over time. Here's a breakdown of| what it means:
#
# 1.  **The Everyday Understanding (The "Where"):**
#     At its most basic, space is the **three-dimensional extent** in which objects and events have relative position and direction. It's the| "where" of everything. When you say "the book is on the table," you're describing its position in space relative to the table. We perceive it as a vast, largely empty void between celestial bodies.
#
# 2.  |**Classical Physics (Newtonian Space - Absolute Container):**
#     In classical physics, as envisioned by Isaac Newton, space was considered an **absolute, immutable, and infinite container**. It was like a fixed, invisible grid that existed independently of anything within| it. Objects moved *through* space, but space itself didn't change or interact with the objects. It was a passive backdrop.
#
# 3.  **Modern Physics (Einstein's Spacetime - Dynamic Fabric):**
# |    Albert Einstein's theories of relativity fundamentally changed our understanding of space (and time).
#     *   **Spacetime:** Einstein showed that space and time are not separate entities but are interwoven into a single, four-dimensional fabric called| **spacetime**.
#     *   **Curvature and Gravity:** The most revolutionary idea is that **mass and energy warp or curve this fabric of spacetime**. This curvature is what we perceive as **gravity**. Objects (like planets or light) don'|t get "pulled" by gravity; they follow the curves in spacetime created by massive objects.
#     *   **Dynamic Participant:** So, space is no longer just a passive, empty stage. It's an **active,| dynamic participant** in the universe, influenced by matter and energy, and in turn, influencing their motion.
#
# 4.  **Cosmological Perspective (Expanding Space):**
#     From a cosmological standpoint, space is not static:
#     *   |**Expansion:** The universe is **expanding**. This isn't objects moving *through* space, but space itself *stretching*, carrying galaxies further apart from each other over time.
#     *   **Origin:** According to the Big Bang| theory, space (along with time, matter, and energy) originated at a single point and has been expanding ever since.
#
# 5.  **Quantum Perspective (The Unknowns):**
#     At the smallest scales, the nature of space| becomes even more mysterious:
#     *   **Quantum Foam:** Some theories suggest that at extremely tiny scales (the Planck length), space isn't smooth but is a chaotic, turbulent "quantum foam" of fluctuating energy.
#     *   |**Discrete vs. Continuous:** There's ongoing debate whether space is continuous (infinitely divisible) or discrete (made up of tiny, indivisible units, like pixels).
#
# **In Summary:**
#
# Space is far more than just emptiness. It|'s the **dynamic, four-dimensional stage** upon which the cosmic drama unfolds, intricately linked with time, matter, and energy. It's curved by mass, it's expanding, and its fundamental nature at the quantum level remains| one of the biggest unanswered questions in physics.|
